# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Import CSV
df = pd.read_csv("design_space.csv")

theta = df['Theta'].values
phi = df['Phi'].values
t_FRP = df['t_FRP'].values
w_f = df['w_f'].values
prestress = df['prestress'].values
E1 = df['E1'].values
